# %% [markdown]
# # **Social Ads and Customer Insights**

# %% [markdown]
# ![Customer insights.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# This notebook explores social media advertising data to uncover patterns in customer decision-making. It walks through various techniques, from exploratory visualizations to analysis customer insights. Although the dataset includes only a few features, it shows that meaningful insights can still be drawn from limited information.

# %% [markdown]
# ### Table of Content
#
# - Data Loading
# - Exploratory Data Analysis
# - Data Cleaning and Preprocessing
# - Evaluation and Summary

# %%
# Suppress warnings for a cleaner notebook output
import warnings
warnings.filterwarnings('ignore')

# Ensure inline plotting for Jupyter notebooks
# %matplotlib inline

# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')  # Use Agg backend for matplotlib
import matplotlib.pyplot as plt
plt.switch_backend('Agg')  # In case only plt is needed, switch to Agg
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc

# Set a seaborn style for plots
sns.set(style="whitegrid")

# %% [markdown]
# ### Data Loading

# %%
# Data Loading
# Read the CSV file located in the same directory
df = pd.read_csv('/content/customer data.csv')

# Display the first few rows to get an overview of the data
print('First five rows of the dataset:')
print(df.head())

# Print DataFrame info to confirm data types and non-null values
print('\nDataFrame information:')
print(df.info())
# Out:
# First five rows of the dataset:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0
#
# DataFrame information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   EstimatedSalary  400 non-null    int64
#  2   Purchased        400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB
# None

# %% [markdown]
# ###  Exploratory Data Analysis
#
# In this section, we examine the dataset both visually and statistically. Even with only a few features, visualizing distributions and relationships can uncover meaningful trends. We’ll use histograms, bar charts, pair plots, and other techniques to explore the data.

# %% [markdown]
# ### Data Cleaning and Preprocessing
#
# The dataset seems well-organized, but it’s always a good practice to inspect for missing values and data type mismatches. Here, the data types align with the expected ones based on the dataset documentation. We also show how to identify and address any potential issues. For larger datasets, these methods can help prevent common errors during data loading and preprocessing.

# %%
# Check for missing values
missing_values = df.isnull().sum()
print('Missing values in each column:')
print(missing_values)

# Ensure that the data types are correct
print('\nData types of the dataframe columns:')
print(df.dtypes)

# For date columns, one would typically convert them using pd.to_datetime.
# In this dataset, there are no date columns to convert.
# Out:
# Missing values in each column:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64
#
# Data types of the dataframe columns:
# Age                int64
# EstimatedSalary    int64
# Purchased          int64
# dtype: object

# %% [markdown]
# ### Evaluation and Summary
#
# The logistic regression model achieved a respectable accuracy on the test set. Even with a limited number of features, classification using Age and Estimated Salary provides meaningful insights. Various visualizations, including histograms, box plots, and ROC curves, help illustrate the data. Future work could explore additional features or ensemble techniques to potentially enhance predictive accuracy.
